# %% [markdown]
# <a href="https://colab.research.google.com/github/giggsy1106/DATA-622-NLP-Homework-files/blob/main/NLP_KOTA_HW6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch -q

# %%
import random
import re
from collections import defaultdict

# Training text (fairy tale)
training_text = """
Once upon a time there was a kingdom far away in the mountains. The kingdom was ruled by a wise and kind king.
The king had a daughter who was brave and clever. One day a dragon appeared near the kingdom and frightened the villagers.
The brave princess decided to face the dragon alone. She walked through the dark forest and found the dragon sleeping near a cave.
The princess spoke gently to the dragon and discovered it was lonely and lost. She invited the dragon to live near the kingdom.
From that day on the dragon protected the kingdom and the princess and the dragon became the best of friends.
The king was proud of his daughter and the kingdom lived happily ever after.
"""

# Build bigram Markov chain
def build_markov_chain(text):
    words = re.findall(r'\w+', text.lower())
    chain = defaultdict(list)
    for i in range(len(words) - 2):
        key = (words[i], words[i + 1])
        chain[key].append(words[i + 2])
    return chain

# Generate story
def generate_story(chain, start_phrase, num_words=80):
    words = re.findall(r'\w+', start_phrase.lower())
    story = list(words)
    key = (story[-2], story[-1])
    for _ in range(num_words):
        next_words = chain.get(key)
        if not next_words:
            break
        next_word = random.choice(next_words)
        story.append(next_word)
        key = (story[-2], story[-1])
    story[0] = story[0].capitalize()
    return ' '.join(story) + '.'

chain = build_markov_chain(training_text)
start_phrase = "Once upon a time there was a kingdom"
story = generate_story(chain, start_phrase, num_words=80)

print("=" * 50)
print("   EXERCISE 1: Markov Chain Story")
print("=" * 50)
print(story)
# Out:
# ==================================================
#    EXERCISE 1: Markov Chain Story
# ==================================================
# Once upon a time there was a kingdom far away in the mountains the kingdom from that day on the dragon became the best of friends the king was proud of his daughter and the kingdom was ruled by a wise and kind king the king was proud of his daughter and the kingdom lived happily ever after.

# %%
from transformers import pipeline

print("Loading GPT-2 model... (first run may take ~1-2 min to download)")

# Load text-generation pipeline
generator = pipeline(
    "text-generation",
    model="gpt2",
    max_new_tokens=300
)

# Story prompt
prompt = (
    "Write a creative story about why it is important to study data science today. "
    "Once upon a time, in a world drowning in data, a young student named Alex "
    "decided to learn data science. Alex discovered"
)

# Generate story
result = generator(
    prompt,
    max_new_tokens=300,
    num_return_sequences=1,
    temperature=0.9,
    top_p=0.95,
    do_sample=True,
    repetition_penalty=1.2
)

print("\n" + "=" * 50)
print("   EXERCISE 2: LLM Story — Why Study Data Science?")
print("=" * 50)
print(result[0]['generated_text'])
# Out:
# Loading GPT-2 model... (first run may take ~1-2 min to download)
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Passing `generation_config` together with generation-related arguments=({'do_sample', 'max_new_tokens', 'temperature', 'top_p', 'repetition_penalty', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=300) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ==================================================
#    EXERCISE 2: LLM Story — Why Study Data Science?
# ==================================================
# Write a creative story about why it is important to study data science today. Once upon a time, in a world drowning in data, a young student named Alex decided to learn data science. Alex discovered the value of this skill through reading stories by scholars and researchers around the globe on some really hard-to read books at Amazon that might help readers better understand their own research questions—and how they should go even more deeply into understanding where others have taken them from beginning point A1 up to B5! He was immediately hooked: After several days he became so excited for his experience with these new projects (notably The Future Is Here!) all over again like never before did we get our hands full exploring everything there looks everywhere else out there right now?
# One day I asked myself if my experiences helped me see potential beyond mere writing blog posts or online interviews when studying psychology as an undergrad…but then one morning after asking such great question(s) who knows what kindOf good way would you take advantage/create results using your current skillset...I had finally come across those same words & answers being used everyday while learning programming language; once i found something interesting which made use OFTECH WITH DATA AND CUSTOMING EVERYTHING IN IT....So thank goodness u got back home.....we've been living together ever since

# %%
import random
import re
from collections import defaultdict

training_text = """
Once upon a time there was a kingdom far away in the mountains. The kingdom was ruled by a wise and kind king.
The king had a daughter who was brave and clever. One day a dragon appeared near the kingdom and frightened the villagers.
The brave princess decided to face the dragon alone. She walked through the dark forest and found the dragon sleeping near a cave.
The princess spoke gently to the dragon and discovered it was lonely and lost. She invited the dragon to live near the kingdom.
From that day on the dragon protected the kingdom and the princess and the dragon became the best of friends.
The king was proud of his daughter and the kingdom lived happily ever after.
"""

def build_markov_chain(text):
    words = re.findall(r'\w+', text.lower())
    chain = defaultdict(list)
    for i in range(len(words) - 2):
        key = (words[i], words[i + 1])
        chain[key].append(words[i + 2])
    return chain

def generate_story(chain, start_phrase, num_words=80):
    words = re.findall(r'\w+', start_phrase.lower())
    story = list(words)
    key = (story[-2], story[-1])
    for _ in range(num_words):
        next_words = chain.get(key)
        if not next_words:
            break
        next_word = random.choice(next_words)
        story.append(next_word)
        key = (story[-2], story[-1])
    story[0] = story[0].capitalize()
    return ' '.join(story) + '.'

chain = build_markov_chain(training_text)
start_phrase = "Once upon a time there was a kingdom"
story = generate_story(chain, start_phrase, num_words=80)

print("=" * 50)
print("   EXERCISE 1: Markov Chain Story")
print("=" * 50)
print(story)
# Out:
# ==================================================
#    EXERCISE 1: Markov Chain Story
# ==================================================
# Once upon a time there was a kingdom far away in the mountains the kingdom and frightened the villagers the brave princess decided to face the dragon protected the kingdom and frightened the villagers the brave princess decided to face the dragon and discovered it was lonely and lost she invited the dragon alone she walked through the dark forest and found the dragon and discovered it was lonely and lost she invited the dragon sleeping near a cave the princess spoke gently to the dragon alone she.

# %%
from transformers import pipeline

print("Loading GPT-2 model...")

generator = pipeline(
    "text-generation",
    model="gpt2",
    max_new_tokens=300
)

prompt = (
    "Write a creative story about why it is important to study data science today. "
    "Once upon a time, in a world drowning in data, a young student named Alex "
    "decided to learn data science. Alex discovered"
)

result = generator(
    prompt,
    max_new_tokens=300,
    num_return_sequences=1,
    temperature=0.9,
    top_p=0.95,
    do_sample=True,
    repetition_penalty=1.2
)

print("\n" + "=" * 50)
print("   EXERCISE 2: LLM Story — Why Study Data Science?")
print("=" * 50)
print(result[0]['generated_text'])
# Out:
# Loading GPT-2 model...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=300) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ==================================================
#    EXERCISE 2: LLM Story — Why Study Data Science?
# ==================================================
# Write a creative story about why it is important to study data science today. Once upon a time, in a world drowning in data, a young student named Alex decided to learn data science. Alex discovered the power of reading social media stories when he went on Google Plus (as well as other forms).
# The value people place here goes far beyond just content and engagement with information or ideas; they have no idea what sort person that was before being asked questions online but also all right now are excited by these big news projects like Facebook & Twitter's growth rate has taken off thanks mostly due outwards from us millennials so this may be true for some too – an interesting way to think deeply into who our audience really needs more than how much money we will make at first base! This would lead you back towards something else… We believe research should take up very little space such which could put your project under closer scrutiny if not already explored even further? If any work were ever done inside academia then obviously anyone interested/determined needed another source field experience there probably wouldn't matter either since most existing sources used old methods over new ones while those often lacked real scientific interest making them somewhat useless unless someone got their head together enough once again because writing experiments doesn'nt do anything wrong 🙂 And remember though many scientists don`t care especially given my lack o m knowledge: I am trying hard anyways haha :) Now let me get through every aspect without touching everything 😉
#
# ) How To Write A Project Review : You can write reviews yourself simply using words included above etc... It isn´ t impossible!! The goal clearly 'is never boring yet does NOT add cost', "only gets worse within 30 days" meaning
